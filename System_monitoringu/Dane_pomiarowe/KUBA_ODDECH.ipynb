# %% [markdown]
# WSZYSTKIE ODDECHY - JEDEN POD DRUGIM NA JEDNYM WYKRESIE <br>
# PRZESUNIETE O OK. 0.5G <br>
# JAK SIE TUTAJ UDA TO DODAC OZNACZENIA NAD WYKRESAMI ZE +0,5N LUB +0,5G

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#pd.read_excel('Excel_Sample.xlsx',sheet_name='Arkusz1',index_col=[0])

# %%
#df.to_excel('Excel_Sample2.xlsx',sheet_name='NewSheet')

# %%
#pd.read_excel('Mateusz_oddech_bezdech_czyli_szum_urządzenia_kopia.xlsx',sheet_name='Arkusz1',index_col=[0],skiprows=range(1,1000))

# %% [markdown]
# https://stackoverflow.com/questions/38560748/python-pandas-dataframe-reading-exact-specified-range-in-an-excel-sheet

# %%
######################################### Mateusz - oddech
# from openpyxl import load_workbook

# wb = load_workbook(filename='Mateusz_oddech_bezdech_czyli_szum_urządzenia_kopia.xlsx', 
#                    read_only=True)

# ws = wb['Arkusz1']

# # Read the cell values into a list of lists
# data_rows = []
# for row in ws['A1000':'D6000']:
#     data_cols = []
#     for cell in row:
#         data_cols.append(cell.value)
#     data_rows.append(data_cols)

# # Transform into dataframe
# import pandas as pd
# df = pd.DataFrame(data_rows)

# %%
df_kuby = pd.read_excel('kuba - oddech 45, bezdech 30 sekund.xlsx', sheet_name = 'Sheet1', skiprows = 600,  nrows= 2000, usecols = 'A:D',names=('mod','x','y','z'))
df_mat = pd.read_excel('Mateusz_oddech_bezdech_czyli_szum_urządzenia_kopia.xlsx', sheet_name = 'Arkusz1', skiprows = 3000,  nrows= 2000, usecols = 'A:D',names=('mod','x','y','z'))
df_karol = pd.read_excel('Karol - oddech - ostatnie 60 sekund.xlsx', sheet_name = 'Sheet1', skiprows = 2200,  nrows= 2000, usecols = 'A:D',names=('mod','x','y','z'))
df_anna = pd.read_excel('ciocia - siadanie+wstawanie z krzesła 47 cm , upadek, oddech 45s.xlsx', sheet_name = 'Sheet1', skiprows = 4700,  nrows= 2000, usecols = 'A:D',names=('mod','x','y','z'))
df_mar = pd.read_excel('Marzena_oddech.xlsx', sheet_name = 'Arkusz1', skiprows = 600,  nrows= 2000, usecols = 'A:D',names=('mod','x','y','z'))

# %%
arr_odd_kuby = df_kuby['x'].to_numpy()
arr_odd_kuby = arr_odd_kuby # +0.07 <-- przesunięcie do porownania na wykresie z szumem
arr_odd_kuby_czas = np.arange(0,len(arr_odd_kuby)*0.03,0.03) # zrobienie rownej dlugosci arraya co zadany odstep czasu

# %%
arr_odd_mat = df_mat['x'].to_numpy()
arr_odd_mat = arr_odd_mat+0.12
arr_odd_mat_czas = np.arange(0,len(arr_odd_mat)*0.03,0.03) # zrobienie rownej dlugosci arraya co zadany odstep czasu

# %%
arr_odd_karol = df_karol['y'].to_numpy()
arr_odd_karol = arr_odd_karol+0.24
arr_odd_karol_czas = np.arange(0,len(arr_odd_karol)*0.03,0.03) # zrobienie rownej dlugosci arraya co zadany odstep czasu

# %%
arr_odd_anna = df_anna['x'].to_numpy()
arr_odd_anna = arr_odd_anna+0.40
arr_odd_anna_czas = np.arange(0,len(arr_odd_anna)*0.03,0.03) # zrobienie rownej dlugosci arraya co zadany odstep czasu

# %%
arr_odd_mar = df_mar['y'].to_numpy()
arr_odd_mar = arr_odd_mar+0.63
arr_odd_mar_czas = np.arange(0,len(arr_odd_mar)*0.03,0.03) # zrobienie rownej dlugosci arraya co zadany odstep czasu

# %%
fig = plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
ax = plt.subplot(111)

line1, = ax.plot(arr_odd_kuby_czas,arr_odd_kuby, label='Kuba')
# line2, = ax.plot(arr_odd_mat_czas,arr_odd_mat, label='Mateusz')
# line3, = ax.plot(arr_odd_karol_czas,arr_odd_karol, label='Karol')
# line4, = ax.plot(arr_odd_anna_czas,arr_odd_anna, label='Anna')
# line5, = ax.plot(arr_odd_mar_czas,arr_odd_mar, label='Marzena')

# Shrink current axis's height by 10% on the bottom
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])

# Put a legend below current axis
ax.legend(loc='upper right', bbox_to_anchor=(0.4, 1.0),
          ncol=3, fancybox=True, shadow=True)
plt.xlabel("czas [s]", fontsize=16)
plt.ylabel("amplituda [G]",fontsize=16)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.tick_params(axis='both', which='minor', labelsize=20)
#plt.ylim(-.17,)
# plt.title("Wykres oddechu pięciu badanych osób")
plt.grid()
# ax.yaxis.set_ticks(np.arange(-0.1,0.5,0.05))


plt.show()

# %%
# NIZEJ JEST DRUKOWANIE FFT, ZOSTAWIE NA POZNIEJ A JEST TEZ W INNYM PLIKU NAZWANYM FFT ODDECH KUBY

# %%
arr = df['x'].to_numpy()

# %%
arr
# Out:
# array([-0.11, -0.12, -0.09, ..., -0.05, -0.05, -0.03])

# %%
from scipy import fft

# %%
fft_res = fft(arr)

# %%
fft_res
# Out:
# array([-178.02      +0.j        ,   -9.31439113+3.94216998j,
#          -6.18605756+4.23342912j, ...,   -1.4306773 -3.5212927j ,
#          -6.18605756-4.23342912j,   -9.31439113-3.94216998j])

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(np.real(fft_res[5:200])) # 5:200 może pominąć peak 
plt.plot(np.imag(fft_res[5:200]))
plt.xlabel('czestotliwosc')
plt.ylabel('amplituda')
plt.title('widmo oddechu Kuby')
# Out:
# Text(0.5, 1.0, 'widmo oddechu Kuby')
